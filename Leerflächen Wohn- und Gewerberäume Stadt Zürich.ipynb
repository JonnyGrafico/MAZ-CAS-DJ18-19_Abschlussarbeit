# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Daten/Gewerbe/Leerflaechen-Gewerbe_Leerflaechen.xlsx', index_col=0, header=0).fillna(0)

#df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)

# %%
df.fillna(0).head()
# Out:
#                leer    2017    2016      2015    2014
# Ganze Stadt  187714  243660  237054  256450.0  264548
# Kreis 1       30550   34710   32201   40945.0   53774
# Rathaus        3504    1940    2261    2261.0    2284
# Hochschulen     670    1187     340     126.0    2218
# Lindenhof      7542   10304    8060    7737.0    7381

# %%
df.dtypes
# Out:
# leer      int64
# 2017      int64
# 2016      int64
# 2015    float64
# 2014      int64
# dtype: object

# %%
df.shape
# Out:
# (47, 5)

# %%
df[['leer', '2016']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-fdb958f5508b> in <module>
# ----> 1 df[['leer', '2016']]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
df.head()
# Out:
#                leer    2017    2016      2015    2014
# Ganze Stadt  187714  243660  237054  256450.0  264548
# Kreis 1       30550   34710   32201   40945.0   53774
# Rathaus        3504    1940    2261    2261.0    2284
# Hochschulen     670    1187     340     126.0    2218
# Lindenhof      7542   10304    8060    7737.0    7381

# %%
# df['2015'] = drinks['2015'].astype(int)

# %%
# df_3 = df_2[['Gemeindenummer', 'Gemeinde', '2016_x', 'Bevölkerungswachstum', 'Wohnungswachstum Total', 'Leerwohnungsziffer']].copy()
# df_3.rename(columns={'2016_x': 'Bevölkerung'}, inplace=True)
# df_3.head(2)

# %%
df.dtypes
# Out:
# leer      int64
# 2017      int64
# 2016      int64
# 2015    float64
# 2014      int64
# dtype: object

# %%
df.iloc[:,0:1].head()
# Out:
#                leer
# Ganze Stadt  187714
# Kreis 1       30550
# Rathaus        3504
# Hochschulen     670
# Lindenhof      7542

# %%
df.iloc[:,0:5].head()
# Out:
#                leer    2017    2016      2015    2014
# Ganze Stadt  187714  243660  237054  256450.0  264548
# Kreis 1       30550   34710   32201   40945.0   53774
# Rathaus        3504    1940    2261    2261.0    2284
# Hochschulen     670    1187     340     126.0    2218
# Lindenhof      7542   10304    8060    7737.0    7381

# %%
df.transpose()
# Out:
#       Ganze Stadt  Kreis 1  Rathaus  Hochschulen  Lindenhof     City  Kreis 2  \
# leer     187714.0  30550.0   3504.0        670.0     7542.0  18834.0  23200.0
# 2017     243660.0  34710.0   1940.0       1187.0    10304.0  21279.0  25173.0
# 2016     237054.0  32201.0   2261.0        340.0     8060.0  21540.0  19439.0
# 2015     256450.0  40945.0   2261.0        126.0     7737.0  30821.0  30347.0
# 2014     264548.0  53774.0   2284.0       2218.0     7381.0  41891.0  34236.0
#
#       Wollishofen  Leimbach     Enge     ...      Höngg  Wipkingen  Kreis 11  \
# leer       2220.0       0.0  20980.0     ...       28.0      562.0   43175.0
# 2017       4227.0       0.0  20946.0     ...      464.0      878.0   65488.0
# 2016       5313.0       0.0  14126.0     ...        0.0      477.0   58697.0
# 2015       3790.0       0.0  26557.0     ...      220.0        0.0   25972.0
# 2014       9101.0     401.0  24734.0     ...        0.0     1240.0   38549.0
#
# ...

# %%
df.dtypes
# Out:
# leer      int64
# 2017      int64
# 2016      int64
# 2015    float64
# 2014      int64
# dtype: object

# %%
df = df[['leer']].astype(str).astype(int).head()

# %%
df.dtypes
# Out:
# leer    int64
# dtype: object

# %%
df = pd.DataFrame(
    np.arange(10).reshape((2, 3)),
    columns=pd.DatetimeIndex(['2015', '2016']))
print(df['2015'])

# %%
# to change use .astype() 
drinks[2] = drinks.leer.astype(int)

# %%
drinks.head()
# Out:
#                leer    2017    2016      voll    2014       2
# Ganze Stadt  187714  243660  237054  256450.0  264548  187714
# Kreis 1       30550   34710   32201   40945.0   53774   30550
# Rathaus        3504    1940    2261    2261.0    2284    3504
# Hochschulen     670    1187     340     126.0    2218     670
# Lindenhof      7542   10304    8060    7737.0    7381    7542

# %%
drinks.dtypes
# Out:
# leer    int64
# voll    int64
# 2       int64
# dtype: object

# %%
drinks.dtypes
# Out:
# leer    int64
# 2017    int64
# 2016    int64
# voll    int64
# 2014    int64
# 2015    int64
# dtype: object

# %%
drinks = drinks[['leer', 'voll']]

# %%
drinks['2017'].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2017'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-260-6a63e50b732f> in <module>
# ...

# %%
drinks
# Out:
#                         leer    voll
# Ganze Stadt           187714  187714
# Kreis 1                30550   30550
# Rathaus                 3504    3504
# Hochschulen              670     670
# Lindenhof               7542    7542
# City                   18834   18834
# Kreis 2                23200   23200
# Wollishofen             2220    2220
# Leimbach                   0       0
# Enge                   20980   20980
# Kreis 3                19407   19407
# Alt-Wiedikon           16268   16268
# Friesenberg                0       0
# Sihlfeld                3139    3139
# Kreis 4                 6808    6808
# Werd                    3639    3639
# Langstrasse             1093    1093
# Hard                    2076    2076
# Kreis 5                 8646    8646
# Gewerbeschule            342     342
# Escher Wyss             8304    8304
# Kreis 6                 3281    3281
# Unterstrass             2744    2744
# Oberstrass               537     537
# ...

# %%
#pd.set_option("display.max_columns", 50)

# %%
df.columns
# Out:
# Int64Index([2018, 2017, 2016, 2015, 2014], dtype='int64')

# %%
df.columns.astype(int)
# Out:
# Int64Index([2018, 2017, 2016, 2015, 2014], dtype='int64')

# %%
df
# Out:
#                                                    2018      2017      2016  \
# Ganze Stadt                                      187714  243660.0  237054.0
# Kreis 1                                           30550   34710.0   32201.0
# Rathaus                                            3504    1940.0    2261.0
# Hochschulen                                         670    1187.0     340.0
# Lindenhof                                          7542   10304.0    8060.0
# City                                              18834   21279.0   21540.0
# Kreis 2                                           23200   25173.0   19439.0
# Wollishofen                                        2220    4227.0    5313.0
# Leimbach                                              0       0.0       0.0
# Enge                                              20980   20946.0   14126.0
# Kreis 3                                           19407   20063.0   22593.0
# ...

# %%
list1 = list(df)

# %%
list1
# Out:
# [2018, 2017, 2016, 2015, 2014]

# %%
#df.info

# %%
df = df[['2018', '2017']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-27cdd33d69ab> in <module>
# ----> 1 df = df[['2018', '2017']]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
df_leerflaeche
# Out:
#                       Leerfläche (m²).1  Unnamed: 6  Unnamed: 11  Unnamed: 3  \
# NaN                                2018        2017  2017.000000      2015.0
# Ganze Stadt                      139664      174381     2.294606    256450.0
# Kreis 1                           23805       29535     3.722381     40945.0
# Rathaus                            1399        1940     1.828309      2261.0
# Hochschulen                         670         797     1.018492       126.0
# Lindenhof                          6963        8158     4.657459      7737.0
# City                              14773       18640     4.492340     30821.0
# Kreis 2                           19520       17542     2.230628     30347.0
# Wollishofen                        1741        2224     1.469252      3790.0
# Leimbach                              0           0     0.000000         0.0
# Enge                              17779       15318     2.533441     26557.0
# ...

# %%
df = pd.read_excel('Daten/Gewerbe/Leerflaechen-Gewerbe_alle.xlsx', header=9).fillna(0)

#df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)

# %%
df.fillna(0).head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN                     2018        2017        2016      2015.0        2014
# Ganze Stadt           187714      243660      237054    256450.0      264548
# Kreis 1                30550       34710       32201     40945.0       53774
# Rathaus                 3504        1940        2261      2261.0        2284
# Hochschulen              670        1187         340       126.0        2218
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# NaN                       2018        2017        2016        2015
# Ganze Stadt             139664      174381      193027      207901
# Kreis 1                  23805       29535       29807       36180
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# ...

# %%
list2 = list(df)

# %%
list2
# Out:
# ['Leerfläche (m²)',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Leerfläche (m²).1',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Leerflächenziffer',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Leerfläche (m²).2',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18']

# %%
df_leerflaeche = df[['Leerfläche (m²)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']]

# %%
df_leerflaeche.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# NaN                     2018        2017        2016      2015.0        2014
# Ganze Stadt           187714      243660      237054    256450.0      264548
# Kreis 1                30550       34710       32201     40945.0       53774
# Rathaus                 3504        1940        2261      2261.0        2284
# Hochschulen              670        1187         340       126.0        2218

# %%
df.rename(columns=df.iloc[0]).drop(df.index[0])
# Out:
#                       2018.0  2017.0  2016.0    2015.0  2014.0  2018.0  \
# Ganze Stadt           187714  243660  237054  256450.0  264548  139664
# Kreis 1                30550   34710   32201   40945.0   53774   23805
# Rathaus                 3504    1940    2261    2261.0    2284    1399
# Hochschulen              670    1187     340     126.0    2218     670
# Lindenhof               7542   10304    8060    7737.0    7381    6963
# City                   18834   21279   21540   30821.0   41891   14773
# Kreis 2                23200   25173   19439   30347.0   34236   19520
# Wollishofen             2220    4227    5313    3790.0    9101    1741
# Leimbach                   0       0       0       0.0     401       0
# Enge                   20980   20946   14126   26557.0   24734   17779
# Kreis 3                19407   20063   22593   38728.0   34681   11823
# Alt-Wiedikon           16268   16327   19741   33457.0   26935   10489
# ...

# %%
df_leerflaeche[:4]
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Kreis 1                30550       34710       32201     40945.0       53774
# Rathaus                 3504        1940        2261      2261.0        2284
# Hochschulen              670        1187         340       126.0        2218
# Lindenhof               7542       10304        8060      7737.0        7381
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# Kreis 1                  23805       29535       29807       36180
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
# Lindenhof                 6963        8158        7725        7374
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# Kreis 1           49692           3.009313     3.722381     3.713889
# Rathaus            1856           1.312454     1.828309     1.280151
# ...

# %%
#df_leerflaeche.rename(columns = header)

# %%
df_leerflaeche.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Kreis 1                30550       34710       32201     40945.0       53774
# Rathaus                 3504        1940        2261      2261.0        2284
# Hochschulen              670        1187         340       126.0        2218
# Lindenhof               7542       10304        8060      7737.0        7381
# City                   18834       21279       21540     30821.0       41891
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# Kreis 1                  23805       29535       29807       36180
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
# Lindenhof                 6963        8158        7725        7374
# City                     14773       18640       20427       26567
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# ...

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

# %%
df_auswahl = df[['2018', '2017']]


#df_auswahl = df[['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1']]



# df_ohnere_total = df[['Industrie - Total', 'Dienste - Total', 'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        #'Pro memoria: Grundstücks- und Wohnungswesen',
#        #'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen'
#         ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-2e842b86821e> in <module>
# ----> 1 df_auswahl = df[['2018', '2017']]
#       2
#       3
#       4 #df_auswahl = df[['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1']]
#       5
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# ...

# %%
df.columns
# Out:
# Index([    2018,     2017,     2016,     2015,     2014, '2018.1', '2017.1',
#        '2016.1', '2015.1', '2014.1', '2018.2', '2017.2', '2016.2', '2015.2',
#        '2014.2', '2018.3', '2018.4', '2018.5', '2018.6'],
#       dtype='object')

# %%
df_auswahl[0:].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-dc5c028e240e> in <module>
# ----> 1 df_auswahl[0:].reset_index()
#
# NameError: name 'df_auswahl' is not defined

# %%
df[0:]

# %%
df.transpose()

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import numpy as np

pyo.init_notebook_mode(connected=True)

np.random.seed(42)
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
)]
fig = go.Figure(data=data)
pyo.iplot(fig, filename='hover-chart-basic')

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import numpy as np

pyo.init_notebook_mode(connected=True)

trace1 = go.Bar(
    x=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
    y=['2014', '2015', '2016', '2017', '2018'],
    name='BE Zoo'
)

trace2 = go.Bar(
    x=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
    y=['2014', '2015', '2016', '2017', '2018'],
    name='ZH Zoo'
)

# trace1 = go.Bar(
#     x=['2014', '2015', '2016', '2017', '2018'],
#     y=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
#     name='SF Zoo'
# )
# trace2 = go.Bar(
#     x=['2014', '2015', '2016', '2017', '2018'],
#     y=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
#     name='LA Zoo'
# )

data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data)
pyo.iplot(fig, filename='hover-chart-basic')


# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='grouped-bar')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...
