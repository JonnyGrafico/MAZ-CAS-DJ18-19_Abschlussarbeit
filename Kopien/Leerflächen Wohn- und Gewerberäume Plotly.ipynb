# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.plotly as py
import plotly.graph_objs as go
# from plotly.offline import init_notebook_mode, iplot

# init_notebook_mode()


import cufflinks as cf
import numpy as np

# import plotly.tools as tls
# tls.embed('https://plot.ly/~cufflinks/8')

# %%
df = pd.read_excel('Daten/Gewerbe/Leerflaechen_Nutzungsart-und-Quartier.xlsx', index_col=0, header=9).fillna(0).astype(int)

#df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)

# %%
df.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN                     2018        2017        2016        2015        2014
# Ganze Stadt           187714      243660      237054      256450      264548
# Kreis 1                30550       34710       32201       40945       53774
# Rathaus                 3504        1940        2261        2261        2284
# Hochschulen              670        1187         340         126        2218
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# NaN                       2018        2017        2016        2015
# Ganze Stadt             139664      174381      193027      207901
# Kreis 1                  23805       29535       29807       36180
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# ...

# %%
df.dtypes
# Out:
# Leerfläche (m²)      int64
# Unnamed: 1           int64
# Unnamed: 2           int64
# Unnamed: 3           int64
# Unnamed: 4           int64
# Leerfläche (m²).1    int64
# Unnamed: 6           int64
# Unnamed: 7           int64
# Unnamed: 8           int64
# Unnamed: 9           int64
# Leerflächenziffer    int64
# Unnamed: 11          int64
# Unnamed: 12          int64
# Unnamed: 13          int64
# Unnamed: 14          int64
# Leerfläche (m²).2    int64
# Unnamed: 16          int64
# Unnamed: 17          int64
# Unnamed: 18          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Leerfläche (m²)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Leerfläche (m²).1', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Leerflächenziffer', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Leerfläche (m²).2',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18'],
#       dtype='object')

# %%
df.shape
# Out:
# (48, 19)

# %%
df_quartiere = df.drop(['Ganze Stadt', 'Kreis 1', 'Kreis 2', 'Kreis 3', 'Kreis 4',
         'Kreis 5', 'Kreis 6', 'Kreis 7', 'Kreis 8', 'Kreis 9', 'Kreis 10', 'Kreis 11', 'Kreis 12'])

# %%
df_quartiere.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN                     2018        2017        2016        2015        2014
# Rathaus                 3504        1940        2261        2261        2284
# Hochschulen              670        1187         340         126        2218
# Lindenhof               7542       10304        8060        7737        7381
# City                   18834       21279       21540       30821       41891
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# NaN                       2018        2017        2016        2015
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
# Lindenhof                 6963        8158        7725        7374
# City                     14773       18640       20427       26567
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# ...

# %%
df_leerflaeche = df_quartiere.iloc[2,2 :].head()

# %%
df_leerflaeche
# Out:
# Unnamed: 2            340
# Unnamed: 3            126
# Unnamed: 4           2218
# Leerfläche (m²).1     670
# Unnamed: 6            797
# Name: Hochschulen, dtype: int64

# %%
df_leerflaeche.plot(kind='bar', figsize=(15,7))

# %%
df_leer = pd.read_excel('Daten/Gewerbe/Leerflaechen_Nutzungsart-und-Quartier.xlsx', header=10, inplace=True).fillna(0).astype(int)

# %%
df_leer.head()
# Out:
#                2018    2017    2016    2015    2014  2018.1  2017.1  2016.1  \
# Ganze Stadt  187714  243660  237054  256450  264548  139664  174381  193027
# Kreis 1       30550   34710   32201   40945   53774   23805   29535   29807
# Rathaus        3504    1940    2261    2261    2284    1399    1940    1315
# Hochschulen     670    1187     340     126    2218     670     797     340
# Lindenhof      7542   10304    8060    7737    7381    6963    8158    7725
#
#              2015.1  2014.1  2018.2  2017.2  2016.2  2015.2  2014.2  2018.3  \
# Ganze Stadt  207901  214900       1       2       2       2       2   31663
# Kreis 1       36180   49692       3       3       3       4       6    2436
# Rathaus        2113    1856       1       1       1       2       1     128
# Hochschulen     126    2218       0       1       0       0       2       0
# Lindenhof      7374    6967       3       4       4       4       4     579
#
#              2018.4  2018.5  2018.6
# ...

# %%
dfx = df_leer.iloc[0:,0:5]

# %%
dfx.head()
# Out:
#                2018    2017    2016    2015    2014
# Ganze Stadt  187714  243660  237054  256450  264548
# Kreis 1       30550   34710   32201   40945   53774
# Rathaus        3504    1940    2261    2261    2284
# Hochschulen     670    1187     340     126    2218
# Lindenhof      7542   10304    8060    7737    7381

# %%
dfy = dfx.drop(['Ganze Stadt', 'Kreis 1', 'Kreis 2', 'Kreis 3', 'Kreis 4',
         'Kreis 5', 'Kreis 6', 'Kreis 7', 'Kreis 8', 'Kreis 9', 'Kreis 10', 'Kreis 11', 'Kreis 12'])
dfy
# Out:
#                        2018   2017   2016   2015   2014
# Rathaus                3504   1940   2261   2261   2284
# Hochschulen             670   1187    340    126   2218
# Lindenhof              7542  10304   8060   7737   7381
# City                  18834  21279  21540  30821  41891
# Wollishofen            2220   4227   5313   3790   9101
# Leimbach                  0      0      0      0    401
# Enge                  20980  20946  14126  26557  24734
# Alt-Wiedikon          16268  16327  19741  33457  26935
# Friesenberg               0      0      0      0      0
# Sihlfeld               3139   3736   2852   5271   7746
# Werd                   3639   2620   7608    610   3026
# Langstrasse            1093   5698   3729   5553   3769
# Hard                   2076  14543    246   1162    251
# Gewerbeschule           342   1902   4177   2344   4311
# Escher Wyss            8304   4011  13405  42565  29332
# Unterstrass            2744   4281   3391   5322   1795
# ...

# %%
df_leerflaeche = df_leerflaeche.drop(['Ganze Stadt', 'Kreis 1', 'Kreis 2', 'Kreis 3', 'Kreis 4',
         'Kreis 5', 'Kreis 6', 'Kreis 7', 'Kreis 8', 'Kreis 9', 'Kreis 10', 'Kreis 11', 'Kreis 12'])
df_leerflaeche.head()

# df_leerflaeche.loc[['Kreis 1', 'Kreis 9'],:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-1278ac6e9f4c> in <module>
#       1 df_leerflaeche = df_leerflaeche.drop(['Ganze Stadt', 'Kreis 1', 'Kreis 2', 'Kreis 3', 'Kreis 4',
# ----> 2          'Kreis 5', 'Kreis 6', 'Kreis 7', 'Kreis 8', 'Kreis 9', 'Kreis 10', 'Kreis 11', 'Kreis 12'])
#       3 df_leerflaeche.head()
#       4
#       5 # df_leerflaeche.loc[['Kreis 1', 'Kreis 9'],:]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3414         return super(Series, self).drop(labels=labels, axis=axis, index=index,
#    3415                                         columns=columns, level=level,
# -> 3416                                         inplace=inplace, errors=errors)
#    3417
#    3418     @Substitution(**_shared_doc_kwargs)
#
# ...

# %%
df.columns

# %%
df_neu = df_leerflaeche.loc[0:,'2018']
df_neu

# %%
df_neu.plot(kind='bar', figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-736dc4d709f5> in <module>
# ----> 1 df_neu.plot(kind='bar', figsize=(15,7))
#
# NameError: name 'df_neu' is not defined

# %%
df_neu.iplot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5d6e97c2e0a3> in <module>
# ----> 1 df_neu.iplot(kind='bar')
#
# NameError: name 'df_neu' is not defined

# %%
leerflaeche = pd.read_excel('Daten/Gewerbe/Leerflaechen_Nutzungsart-und-Quartier.xlsx', header=10).fillna(0).astype(int)

# %%
leerflaeche.iloc[0:,0:5].head()
# Out:
#                2018    2017    2016    2015    2014
# Ganze Stadt  187714  243660  237054  256450  264548
# Kreis 1       30550   34710   32201   40945   53774
# Rathaus        3504    1940    2261    2261    2284
# Hochschulen     670    1187     340     126    2218
# Lindenhof      7542   10304    8060    7737    7381

# %%
leerflaeche.index.name='Quartier'

# %%
leerflaeche.head()
# Out:
#                2018    2017    2016    2015    2014  2018.1  2017.1  2016.1  \
# Quartier
# Ganze Stadt  187714  243660  237054  256450  264548  139664  174381  193027
# Kreis 1       30550   34710   32201   40945   53774   23805   29535   29807
# Rathaus        3504    1940    2261    2261    2284    1399    1940    1315
# Hochschulen     670    1187     340     126    2218     670     797     340
# Lindenhof      7542   10304    8060    7737    7381    6963    8158    7725
#
#              2015.1  2014.1  2018.2  2017.2  2016.2  2015.2  2014.2  2018.3  \
# Quartier
# Ganze Stadt  207901  214900       1       2       2       2       2   31663
# Kreis 1       36180   49692       3       3       3       4       6    2436
# Rathaus        2113    1856       1       1       1       2       1     128
# Hochschulen     126    2218       0       1       0       0       2       0
# Lindenhof      7374    6967       3       4       4       4       4     579
#
# ...

# %%
df1 = leerflaeche.iloc[0:,0:1].head()

# %%
df1.plot(kind='bar', figsize=(15,7))

# df1.plot(kind='bar', figsize=(15,7))

# %%
df1.iplot(kind='bar', color='red')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jonnygrafico/49.embed" height="525px" width="100%"></iframe>

# %%
# data = [
#     go.Bar(
#         x=[0, 1, 2, 3, 4, 5, 6, 7, 8],
#         y=[0, 1, 2, 3, 4, 5, 6, 7, 8]
#     )
# ]
# layout = go.Layout(
#     autosize=False,
#     width=500,
#     height=500,
#     margin=dict(
#         l=50,
#         r=50,
#         b=100,
#         t=100,
#         pad=4
#     ),
#     paper_bgcolor='#7f7f7f',
#     plot_bgcolor='#c7c7c7'
# )
# fig = go.Figure(data=data, layout=layout)
# py.plot(fig, filename='size-margins')


# # plot_url = py.plot(fig, filename='size-margins')

# %%
df1 = [
    go.Bar(
        x=[1, 2, 3],
        y=[1, 3, 1]
    )
]

config = {
    'linkText': "Let's visit plot.ly !!!",
    'scrollZoom': False,
    'displayModeBar': True,
    'editable': True
}
iplot(df1, config=config)
# Out:
# <div id="28618eb5-dbff-429b-93f5-c9dbc6341827" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("28618eb5-dbff-429b-93f5-c9dbc6341827", [{"x": [1, 2, 3], "y": [1, 3, 1], "type": "bar", "uid": "0b9e900e-4d94-4c75-b276-1e6a6674d02e"}], {}, {"linkText": "Let's visit plot.ly !!!", "scrollZoom": false, "displayModeBar": true, "editable": true, "showLink": false, "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("28618eb5-dbff-429b-93f5-c9dbc6341827"));});</script>

# %%
# df1 = [
#     go.bar(
#         x=['Quartier'],
#         y=[0, 1, 2, 3, 4, 5, 6, 7, 8]
#     )
# ]
# layout = go.Layout(
#     title='Global Font',
#     font=dict(
#         family='Courier New, monospace',
#         size=18,
#         color='#7f7f7f'
#     )
# )
# fig = go.Figure(data=df1, layout=layout)
# py.plot(fig, filename='global-font')

# # py.plot(fig, filename='global-font')
# # plot_url = py.plot(fig, filename='global-font')

# %%
# Create randome data
df = pd.DataFrame(np.random.randn(100,4), columns='Col1 Col2 Col3 Col4'.split())
df.head(2)
# Out:
#        Col1      Col2      Col3      Col4
# 0 -0.740369  2.699697 -0.871822  0.813999
# 1  0.627325 -1.145532  0.537653  0.742746

# %%
# Plot bars
df.iplot(kind='bar')
# Out:
# /Users/jonnygrafico/.virtualenvs/masterEV/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jonnygrafico/47.embed" height="525px" width="100%"></iframe>

# %%
# Create randome data
df = pd.DataFrame(np.random.randn(100,4), columns='Col1 Col2 Col3 Col4'.split())
df.head(2)
# Out:
#        Col1      Col2      Col3      Col4
# 0  0.232441  1.349576 -0.675114  1.341952
# 1 -1.210961 -0.716271  0.881668 -0.285804

# %%
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)         # initiate notebook for offline plot

trace0 = Bar(
  x=[1, 2, 3, 4],
  y=[10, 15, 13, 17]
)
trace1 = Scatter(
  x=[1, 2, 3, 4],
  y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

iplot(data)               # use plotly.offline.iplot for offline plot
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-42143fab05e8> in <module>
#       3 init_notebook_mode(connected=True)         # initiate notebook for offline plot
#       4
# ----> 5 trace0 = Bar(
#       6   x=[1, 2, 3, 4],
#       7   y=[10, 15, 13, 17]
#
# NameError: name 'Bar' is not defined

# %%
# import cufflinks as cf
# iplot(cf.datagen.lines().iplot(asFigure=True,
#                                kind='bar',xTitle='Dates',yTitle='Returns',title='Returns'))

import cufflinks as cf
iplot(cf.datagen.lines().iplot(asFigure=True,
                               kind='bar',xTitle='Dates',yTitle='Returns',title='Returns'))

# %%
df1.iplot(kind='bar', yTitle='Fläche in 1000 m2', title='Büro-Leerflächen nach Kreisen in der Stadt Zürich', filename='Büro-Leerflächen nach Kreisen in der Stadt Zürich')

# df1.iplot(kind='bar')

# %%
# df1 = pd.DataFrame(np.random.rand(44, 4), columns=['2018', 'B', 'C', 'D'])
# row = df1.iloc[2]
# row.iplot(kind='bar', filename='asd')
