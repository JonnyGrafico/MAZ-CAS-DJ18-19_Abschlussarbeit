# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# import plotly.plotly as py
import plotly.offline as pyo
import plotly.graph_objs as go

pyo.init_notebook_mode(connected=True)

import cufflinks as cf

# import plotly.tools as tls
# tls.embed('https://plot.ly/~cufflinks/8')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Bauprojekte Stadt Zürich – Anzahl Projekte im Bau 2017

# %%
df = pd.read_excel('Daten/Bauprojekte/Bauprojekte_im_Bau.xlsx', header=7)
# .replace("\n"," ", regex=True)
df
# Out:
#    Unnamed: 0 Projekte (Anzahl)      Unnamed: 2     Unnamed: 3  \
# 0        Jahr    Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau
# 1        2008               110              29             28
# 2        2009               106              25             31
# 3        2010               106              25             31
# 4        2011               113              28             33
# 5        2012               108              27             33
# 6        2013               109              28             30
# 7        2014               106              28             30
# 8        2015               106              28             33
# 9        2016               104              29             30
# 10       2017               106              26             30
#
#              Unnamed: 4          Unnamed: 5 Bausumme (1000 Fr.)  \
# 0   Nichtwohnen\nNeubau  Nichtwohnen\nUmbau      Alle\nProjekte
# 1                    23                  30             3943891
# ...

# %%
df_projekte = df.iloc[[10], [0,2,3,4,5]]

# %%
df_projekte.columns = ['Jahr',
                       'Projekte – Wohnen Neubau',
                       'Projekte – Wohnen Umbau',
                       'Projekte – Nichtwohnen Neubau',
                       'Projekte – Nichtwohnen Umbau']

# %%
df_projekte
# Out:
#     Jahr Projekte – Wohnen Neubau Projekte – Wohnen Umbau  \
# 10  2017                       26                      30
#
#    Projekte – Nichtwohnen Neubau Projekte – Nichtwohnen Umbau
# 10                            19                           31

# %%
trace1 = go.Bar(
    x=df_projekte.Jahr,
    y=df_projekte['Projekte – Wohnen Neubau'], 
    name="Projekte – Wohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
trace2 = go.Bar(
    x=df_projekte.Jahr,
    y=df_projekte['Projekte – Nichtwohnen Neubau'], 
    name="Projekte – Nichtwohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
trace3 = go.Bar(
    x=df_projekte.Jahr,
    y=df_projekte['Projekte – Wohnen Umbau'], 
    name="Projekte – Wohnen Umbau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
trace4 = go.Bar(
    x=df_projekte.Jahr,
    y=df_projekte['Projekte – Nichtwohnen Umbau'], 
    name="Projekte – Nichtwohnen Umbau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
data = [trace1, trace2, trace3, trace4]

layout = go.Layout(
    title='Bauprojekte Stadt Zürich – Anzahl Projekte im Bau – 2017',
    font=dict(family='Arial, sans-serif', size=14, color='#7f7f7f'),
    autosize=False,
    width=900,
    height=600,
    bargroupgap=0.1,
    bargap=0.2,

    xaxis=dict(
        title='Stadt Zürich',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        tickwidth=1,
        ticklen=10,
        automargin=True
    ),
    
    yaxis=dict(
        title='Anzahl Bauprojekte',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        rangemode='tozero',
        nticks=8,
        exponentformat='none',
        tickwidth=1,
        ticklen=10,
        automargin=True
    )
)

fig = go.Figure(data=data, layout=layout)
pyo.iplot(fig, filename='hover-chart-basic')
# Out:
# <div id="577bb2dd-df6a-452b-a581-497e155521bf" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("577bb2dd-df6a-452b-a581-497e155521bf", [{"name": "Projekte \u2013 Wohnen Neubau", "x": [2017], "y": [26], "type": "bar", "uid": "c2332105-a2c3-4841-baef-a8e324288985"}, {"name": "Projekte \u2013 Nichtwohnen Neubau", "x": [2017], "y": [19], "type": "bar", "uid": "a8903a0a-6535-4539-89b6-9f9d74950f06"}, {"name": "Projekte \u2013 Wohnen Umbau", "x": [2017], "y": [30], "type": "bar", "uid": "769cd885-c254-4cdf-ae0b-1112cc5e5964"}, {"name": "Projekte \u2013 Nichtwohnen Umbau", "x": [2017], "y": [31], "type": "bar", "uid": "d741ff02-1316-4822-aa72-6cea6bda2656"}], {"autosize": false, "bargap": 0.2, "bargroupgap": 0.1, "font": {"color": "#7f7f7f", "family": "Arial, sans-serif", "size": 14}, "height": 600, "titl
# ...

# %% [markdown]
# # Bauprojekte im Bau Stadt Zürich – Bausumme 2017

# %%
df = pd.read_excel('Daten/Bauprojekte/Bauprojekte_im_Bau.xlsx', header=7)
# .replace("\n"," ", regex=True)
df
# Out:
#    Unnamed: 0 Projekte (Anzahl)      Unnamed: 2     Unnamed: 3  \
# 0        Jahr    Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau
# 1        2008               110              29             28
# 2        2009               106              25             31
# 3        2010               106              25             31
# 4        2011               113              28             33
# 5        2012               108              27             33
# 6        2013               109              28             30
# 7        2014               106              28             30
# 8        2015               106              28             33
# 9        2016               104              29             30
# 10       2017               106              26             30
#
#              Unnamed: 4          Unnamed: 5 Bausumme (1000 Fr.)  \
# 0   Nichtwohnen\nNeubau  Nichtwohnen\nUmbau      Alle\nProjekte
# 1                    23                  30             3943891
# ...

# %%
df_bausumme = df.iloc[[10], [0,7,8,9,10]]

# %%
df_bausumme
# Out:
#    Unnamed: 0 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 10       2017    2744443     413530    2215230     1769264

# %%
df_bausumme.columns = ['Jahr',
                       'Bausumme – Wohnen Neubau',
                       'Bausumme – Wohnen Umbau',
                       'Bausumme – Nichtwohnen Neubau',
                       'Bausumme – Nichtwohnen Umbau']

# %%
df_bausumme
# Out:
#     Jahr Bausumme – Wohnen Neubau Bausumme – Wohnen Umbau  \
# 10  2017                  2744443                  413530
#
#    Bausumme – Nichtwohnen Neubau Bausumme – Nichtwohnen Umbau
# 10                       2215230                      1769264

# %%
df_bausumme_gerundet = df_bausumme.apply(lambda x: x/1000000)

# %%
# df_XX = df_bausumme.apply(lambda x: x/1000000)

# %%
df_bausumme_gerundet
# Out:
#         Jahr Bausumme – Wohnen Neubau Bausumme – Wohnen Umbau  \
# 10  0.002017                  2.74444                 0.41353
#
#    Bausumme – Nichtwohnen Neubau Bausumme – Nichtwohnen Umbau
# 10                       2.21523                      1.76926

# %%
trace1 = go.Bar(
    x=df_bausumme_gerundet.Jahr,
    y=df_bausumme_gerundet['Bausumme – Wohnen Neubau'], 
    name="Bausumme – Wohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
trace2 = go.Bar(
    x=df_bausumme_gerundet.Jahr,
    y=df_bausumme_gerundet['Bausumme – Nichtwohnen Neubau'], 
    name="Bausumme – Nichtwohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
# trace3 = go.Bar(
#     x=df_bausumme_gerundet.Jahr,
#     y=df_bausumme_gerundet['Bausumme – Wohnen Umbau'], 
#     name="Bausumme – Wohnen Umbau",
# #     marker=dict(color='#FFD700') # set the marker color to gold
# )
# trace4 = go.Bar(
#     x=df_bausumme_gerundet.Jahr,
#     y=df_bausumme_gerundet['Bausumme – Nichtwohnen Umbau'], 
#     name="Bausumme – Nichtwohnen Umbau",
# #     marker=dict(color='#FFD700') # set the marker color to gold
# )
data = [trace1, trace2]

layout = go.Layout(
    title='Bauprojekte im Bau Stadt Zürich – Bausumme – 2017',
    font=dict(family='Arial, sans-serif', size=14, color='#7f7f7f'),
    autosize=False,
    width=900,
    height=600,
    bargroupgap=0.1,
    bargap=0.2,

    xaxis=dict(
        title='Stadt Zürich',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        tickwidth=1,
        ticklen=10,
        automargin=True
    ),
    
    yaxis=dict(
        title='Milliarden Franken',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        rangemode='tozero',
        nticks=8,
        exponentformat='none',
        tickwidth=1,
        ticklen=10,
        automargin=True
    )
)

fig = go.Figure(data=data, layout=layout)
pyo.iplot(fig, filename='hover-chart-basic')
# Out:
# <div id="c29c7e05-d60e-48e3-8c5c-089b267a9dd5" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c29c7e05-d60e-48e3-8c5c-089b267a9dd5", [{"name": "Bausumme \u2013 Wohnen Neubau", "x": [0.002017], "y": [2.744443], "type": "bar", "uid": "0b5b48ff-459b-490b-8e5b-1bc7f5c3cfe3"}, {"name": "Bausumme \u2013 Nichtwohnen Neubau", "x": [0.002017], "y": [2.21523], "type": "bar", "uid": "1135f3ff-e441-415f-a9b7-483f8b7e1e2f"}], {"autosize": false, "bargap": 0.2, "bargroupgap": 0.1, "font": {"color": "#7f7f7f", "family": "Arial, sans-serif", "size": 14}, "height": 600, "title": {"text": "Bauprojekte im Bau Stadt Z\u00fcrich \u2013 Bausumme \u2013 2017"}, "width": 900, "xaxis": {"automargin": true, "ticklen": 10, "tickwidth": 1, "title": {"font": {"color": "#7f7f7f", "family": "Arial, sans-serif", "size": 12}, "t
# ...

# %% [markdown]
# # Bauprojekte im Bau Stadt Zürich – Rauminhalt – 2017

# %%
df = pd.read_excel('Daten/Bauprojekte/Bauprojekte_im_Bau.xlsx', header=7)
df
# Out:
#    Unnamed: 0 Projekte (Anzahl)      Unnamed: 2     Unnamed: 3  \
# 0        Jahr    Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau
# 1        2008               110              29             28
# 2        2009               106              25             31
# 3        2010               106              25             31
# 4        2011               113              28             33
# 5        2012               108              27             33
# 6        2013               109              28             30
# 7        2014               106              28             30
# 8        2015               106              28             33
# 9        2016               104              29             30
# 10       2017               106              26             30
#
#              Unnamed: 4          Unnamed: 5 Bausumme (1000 Fr.)  \
# 0   Nichtwohnen\nNeubau  Nichtwohnen\nUmbau      Alle\nProjekte
# 1                    23                  30             3943891
# ...

# %%
df_rauminhalt = df.iloc[[10], [0,12,14]]

# %%
df_rauminhalt
# Out:
#    Unnamed: 0 Unnamed: 12 Unnamed: 14
# 10       2017     3618540     2252621

# %%
df_rauminhalt.columns = ['Jahr',
                       'Rauminhalt – Wohnen Neubau',
                       'Rauminhalt – Nichtwohnen Neubau']

# %%
df_rauminhalt
# Out:
#     Jahr Rauminhalt – Wohnen Neubau Rauminhalt – Nichtwohnen Neubau
# 10  2017                    3618540                         2252621

# %%
trace1 = go.Bar(
    x=df_rauminhalt.Jahr,
    y=df_rauminhalt['Rauminhalt – Wohnen Neubau'], 
    name="Rauminhalt – Wohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)
trace2 = go.Bar(
    x=df_rauminhalt.Jahr,
    y=df_rauminhalt['Rauminhalt – Nichtwohnen Neubau'], 
    name="Rauminhalt – Nichtwohnen Neubau",
#     marker=dict(color='#FFD700') # set the marker color to gold
)

data = [trace1, trace2]

layout = go.Layout(
    title='Bauprojekte im Bau Stadt Zürich – Rauminhalt – 2017',
    font=dict(family='Arial, sans-serif', size=14, color='#7f7f7f'),
    autosize=False,
    width=900,
    height=600,
    bargroupgap=0.1,
    bargap=0.2,

    xaxis=dict(
        title='Stadt Zürich',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        tickwidth=1,
        ticklen=10,
        automargin=True
    ),
    
    yaxis=dict(
        title='Kubikmeter (m³)',
        titlefont=dict(family='Arial, sans-serif', size=12, color='#7f7f7f'),
        rangemode='tozero',
        nticks=8,
        exponentformat='none',
        tickwidth=1,
        ticklen=10,
        automargin=True
    )
)

fig = go.Figure(data=data, layout=layout)
pyo.iplot(fig, filename='hover-chart-basic')
# Out:
# <div id="cc87a67b-5444-4636-8cd2-3a565475981c" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cc87a67b-5444-4636-8cd2-3a565475981c", [{"name": "Rauminhalt \u2013 Wohnen Neubau", "x": [2017], "y": [3618540], "type": "bar", "uid": "2c5dc359-5ebd-4b2d-88f5-9d5955ffe180"}, {"name": "Rauminhalt \u2013 Nichtwohnen Neubau", "x": [2017], "y": [2252621], "type": "bar", "uid": "18a4c852-52b0-48b7-b887-22fd11f6b053"}], {"autosize": false, "bargap": 0.2, "bargroupgap": 0.1, "font": {"color": "#7f7f7f", "family": "Arial, sans-serif", "size": 14}, "height": 600, "title": {"text": "Bauprojekte im Bau Stadt Z\u00fcrich \u2013 Rauminhalt \u2013 2017"}, "width": 900, "xaxis": {"automargin": true, "ticklen": 10, "tickwidth": 1, "title": {"font": {"color": "#7f7f7f", "family": "Arial, sans-serif", "size": 12}, "text
# ...

# %%
list1=(df)

# %%
list1
# Out:
#    Unnamed: 0 Projekte (Anzahl)     Unnamed: 2    Unnamed: 3  \
# 0        Jahr     Alle Projekte  Wohnen Neubau  Wohnen Umbau
# 1        2008               110             29            28
# 2        2009               106             25            31
# 3        2010               106             25            31
# 4        2011               113             28            33
# 5        2012               108             27            33
# 6        2013               109             28            30
# 7        2014               106             28            30
# 8        2015               106             28            33
# 9        2016               104             29            30
# 10       2017               106             26            30
#
#             Unnamed: 4         Unnamed: 5 Bausumme (1000 Fr.)     Unnamed: 7  \
# 0   Nichtwohnen Neubau  Nichtwohnen Umbau       Alle Projekte  Wohnen Neubau
# ...

# %%
df1
# Out:
#    Unnamed: 0 Projekte (Anzahl)     Unnamed: 2    Unnamed: 3  \
# 0        Jahr     Alle Projekte  Wohnen Neubau  Wohnen Umbau
# 1        2008               110             29            28
# 2        2009               106             25            31
# 3        2010               106             25            31
# 4        2011               113             28            33
# 5        2012               108             27            33
# 6        2013               109             28            30
# 7        2014               106             28            30
# 8        2015               106             28            33
# 9        2016               104             29            30
# 10       2017               106             26            30
#
#             Unnamed: 4         Unnamed: 5 Bausumme (1000 Fr.)     Unnamed: 7  \
# 0   Nichtwohnen Neubau  Nichtwohnen Umbau       Alle Projekte  Wohnen Neubau
# ...

# %%
df = pd.read_excel('Daten/Bauprojekte/Bauprojekte_im_Bau.xlsx', header=9)
# .replace("\n"," ", inplace=True)
# .replace('\n',' ', regex=True)

df
# Out:
#    Jahr  Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau  Nichtwohnen\nNeubau  \
# 0  2008             110              29             28                   23
# 1  2009             106              25             31                   25
# 2  2010             106              25             31                   21
# 3  2011             113              28             33                   22
# 4  2012             108              27             33                   20
# 5  2013             109              28             30                   22
# 6  2014             106              28             30                   18
# 7  2015             106              28             33                   17
# 8  2016             104              29             30                   16
# 9  2017             106              26             30                   19
#
#    Nichtwohnen\nUmbau  Alle\nProjekte.1  Wohnen\nNeubau.1  Wohnen\nUmbau.1  \
# ...

# %%
df5 = df.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df5.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-268-cc9261ceb2ca> in <module>
# ----> 1 df5.columns
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
df.to_excel('Daten/Bauprojekte/vvv.xlsx')

# %%
df8 = pd.read_excel('Daten/Bauprojekte/vvv.xlsx')
df8
# Out:
#    Jahr  Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau  Nichtwohnen\nNeubau  \
# 0  2008             110              29             28                   23
# 1  2009             106              25             31                   25
# 2  2010             106              25             31                   21
# 3  2011             113              28             33                   22
# 4  2012             108              27             33                   20
# 5  2013             109              28             30                   22
# 6  2014             106              28             30                   18
# 7  2015             106              28             33                   17
# 8  2016             104              29             30                   16
# 9  2017             106              26             30                   19
#
#    Nichtwohnen\nUmbau  Alle\nProjekte.1  Wohnen\nNeubau.1  Wohnen\nUmbau.1  \
# ...

# %%
df8.columns
# Out:
# Index(['Jahr', 'Alle\nProjekte', 'Wohnen\nNeubau', 'Wohnen\nUmbau',
#        'Nichtwohnen\nNeubau', 'Nichtwohnen\nUmbau', 'Alle\nProjekte.1',
#        'Wohnen\nNeubau.1', 'Wohnen\nUmbau.1', 'Nichtwohnen\nNeubau.1',
#        'Nichtwohnen\nUmbau.1', 'Alle\nProjekte.2', 'Wohnen\nNeubau.2',
#        'Wohnen\nUmbau.2', 'Nichtwohnen\nNeubau.2', 'Nichtwohnen\nUmbau.2'],
#       dtype='object')

# %%
df.replace(to_replace=["\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True)
df
# Out:
#    Jahr  Alle\nProjekte  Wohnen\nNeubau  Wohnen\nUmbau  Nichtwohnen\nNeubau  \
# 0  2008             110              29             28                   23
# 1  2009             106              25             31                   25
# 2  2010             106              25             31                   21
# 3  2011             113              28             33                   22
# 4  2012             108              27             33                   20
# 5  2013             109              28             30                   22
# 6  2014             106              28             30                   18
# 7  2015             106              28             33                   17
# 8  2016             104              29             30                   16
# 9  2017             106              26             30                   19
#
#    Nichtwohnen\nUmbau  Alle\nProjekte.1  Wohnen\nNeubau.1  Wohnen\nUmbau.1  \
# ...

# %%
df.columns
# Out:
# Index(['Jahr', 'Alle\nProjekte', 'Wohnen\nNeubau', 'Wohnen\nUmbau',
#        'Nichtwohnen\nNeubau', 'Nichtwohnen\nUmbau', 'Alle\nProjekte.1',
#        'Wohnen\nNeubau.1', 'Wohnen\nUmbau.1', 'Nichtwohnen\nNeubau.1',
#        'Nichtwohnen\nUmbau.1', 'Alle\nProjekte.2', 'Wohnen\nNeubau.2',
#        'Wohnen\nUmbau.2', 'Nichtwohnen\nNeubau.2', 'Nichtwohnen\nUmbau.2'],
#       dtype='object')

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-206-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df6
# Out:
# Index(['Jahr', 'Alle\nProjekte', 'Wohnen\nNeubau', 'Wohnen\nUmbau',
#        'Nichtwohnen\nNeubau', 'Nichtwohnen\nUmbau', 'Alle\nProjekte.1',
#        'Wohnen\nNeubau.1', 'Wohnen\nUmbau.1', 'Nichtwohnen\nNeubau.1',
#        'Nichtwohnen\nUmbau.1', 'Alle\nProjekte.2', 'Wohnen\nNeubau.2',
#        'Wohnen\nUmbau.2', 'Nichtwohnen\nNeubau.2', 'Nichtwohnen\nUmbau.2'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Jahr', 'Alle\nProjekte', 'Wohnen\nNeubau', 'Wohnen\nUmbau',
#        'Nichtwohnen\nNeubau', 'Nichtwohnen\nUmbau', 'Alle\nProjekte.1',
#        'Wohnen\nNeubau.1', 'Wohnen\nUmbau.1', 'Nichtwohnen\nNeubau.1',
#        'Nichtwohnen\nUmbau.1', 'Alle\nProjekte.2', 'Wohnen\nNeubau.2',
#        'Wohnen\nUmbau.2', 'Nichtwohnen\nNeubau.2', 'Nichtwohnen\nUmbau.2'],
#       dtype='object')

# %%
# df.reset_index(inplace=True)
# df.head()

# %%
list2=(df)

# %%
list2.dtypes
# Out:
# Jahr                      int64
# Alle\nProjekte            int64
# Wohnen\nNeubau            int64
# Wohnen\nUmbau             int64
# Nichtwohnen\nNeubau       int64
# Nichtwohnen\nUmbau        int64
# Alle\nProjekte.1          int64
# Wohnen\nNeubau.1          int64
# Wohnen\nUmbau.1           int64
# Nichtwohnen\nNeubau.1     int64
# Nichtwohnen\nUmbau.1      int64
# Alle\nProjekte.2          int64
# Wohnen\nNeubau.2          int64
# Wohnen\nUmbau.2          object
# Nichtwohnen\nNeubau.2     int64
# Nichtwohnen\nUmbau.2     object
# dtype: object

# %%
list3 = []
for elem1, elem2 in zip(list1, list2):
    elem = elem1, elem2
    list3.append(elem)

# %%
df1 = pd.read_excel('Daten/Bauprojekte/Bauprojekte_im_Bau.xlsx',index_col=None, header=7
                   ).replace('–', np.nan)

# %%
df1.columns = list3

# %%
df1.columns
# Out:
# Index([                     ('Unnamed: 0', 'Jahr'),
#            ('Projekte (Anzahl)', 'Alle\nProjekte'),
#                   ('Unnamed: 2', 'Wohnen\nNeubau'),
#                    ('Unnamed: 3', 'Wohnen\nUmbau'),
#              ('Unnamed: 4', 'Nichtwohnen\nNeubau'),
#               ('Unnamed: 5', 'Nichtwohnen\nUmbau'),
#        ('Bausumme (1000 Fr.)', 'Alle\nProjekte.1'),
#                 ('Unnamed: 7', 'Wohnen\nNeubau.1'),
#                  ('Unnamed: 8', 'Wohnen\nUmbau.1'),
#            ('Unnamed: 9', 'Nichtwohnen\nNeubau.1'),
#            ('Unnamed: 10', 'Nichtwohnen\nUmbau.1'),
#            ('Rauminhalt (m³)', 'Alle\nProjekte.2'),
#                ('Unnamed: 12', 'Wohnen\nNeubau.2'),
#                 ('Unnamed: 13', 'Wohnen\nUmbau.2'),
#           ('Unnamed: 14', 'Nichtwohnen\nNeubau.2'),
#            ('Unnamed: 15', 'Nichtwohnen\nUmbau.2')],
#       dtype='object')

# %%
df1.dtypes
# Out:
# (Unnamed: 0, Jahr)                         object
# (Projekte (Anzahl), Alle\nProjekte)        object
# (Unnamed: 2, Wohnen\nNeubau)               object
# (Unnamed: 3, Wohnen\nUmbau)                object
# (Unnamed: 4, Nichtwohnen\nNeubau)          object
# (Unnamed: 5, Nichtwohnen\nUmbau)           object
# (Bausumme (1000 Fr.), Alle\nProjekte.1)    object
# (Unnamed: 7, Wohnen\nNeubau.1)             object
# (Unnamed: 8, Wohnen\nUmbau.1)              object
# (Unnamed: 9, Nichtwohnen\nNeubau.1)        object
# (Unnamed: 10, Nichtwohnen\nUmbau.1)        object
# (Rauminhalt (m³), Alle\nProjekte.2)        object
# (Unnamed: 12, Wohnen\nNeubau.2)            object
# (Unnamed: 13, Wohnen\nUmbau.2)             object
# (Unnamed: 14, Nichtwohnen\nNeubau.2)       object
# (Unnamed: 15, Nichtwohnen\nUmbau.2)        object
# dtype: object

# %%
df2 = df1.iloc[[1,10], [0,2,3,5,7,9]]

# %%
df2
# Out:
#    (Unnamed: 0, Jahr) (Unnamed: 2, Wohnen\nNeubau)  \
# 1                2008                           29
# 10               2017                           26
#
#    (Unnamed: 3, Wohnen\nUmbau) (Unnamed: 5, Nichtwohnen\nUmbau)  \
# 1                           28                               30
# 10                          30                               31
#
#    (Unnamed: 7, Wohnen\nNeubau.1) (Unnamed: 9, Nichtwohnen\nNeubau.1)
# 1                         1909389                              938757
# 10                        2744443                             2215230

# %%
# df2 = df.columns
