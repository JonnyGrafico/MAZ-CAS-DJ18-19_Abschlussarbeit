# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Daten/Gewerbe/Leerflaechen-Gewerbe_alle.xlsx', header=9).fillna(0).astype(int)

#df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-01cc625d3abe> in <module>
# ----> 1 df = pd.read_excel('Daten/Gewerbe/Leerflaechen-Gewerbe_alle.xlsx', header=9).fillna(0).astype(int)
#       2
#       3 #df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     392             self.book = xlrd.open_workbook(file_contents=data)
#     393         elif isinstance(self._io, compat.string_types):
# --> 394             self.book = xlrd.open_workbook(self._io)
#     395         else:
#     396             raise ValueError('Must explicitly set engine if not passing in'
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Daten/Gewerbe/Leerflaechen-Gewerbe_alle.xlsx'

# %%
df.fillna(0).head()

# %%
list1 = list(df)

# %%
list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-32e3a55f6bef> in <module>
# ----> 1 list1
#
# NameError: name 'list1' is not defined

# %%
#df.info

# %%
df_leerflaeche = df[['Leerfläche (m²).1', 'Unnamed: 6', 'Unnamed: 11', 'Unnamed: 3', 'Unnamed: 4']]

# %%
df_leerflaeche
# Out:
#                       Leerfläche (m²).1  Unnamed: 6  Unnamed: 11  Unnamed: 3  \
# NaN                                2018        2017         2017        2015
# Ganze Stadt                      139664      174381            2      256450
# Kreis 1                           23805       29535            3       40945
# Rathaus                            1399        1940            1        2261
# Hochschulen                         670         797            1         126
# Lindenhof                          6963        8158            4        7737
# City                              14773       18640            4       30821
# Kreis 2                           19520       17542            2       30347
# Wollishofen                        1741        2224            1        3790
# Leimbach                              0           0            0           0
# Enge                              17779       15318            2       26557
# Kreis 3                           11823       14315            1       38728
# Alt-Wiedikon                      10489       12785            2       33457
# Friesenberg                           0           0            0           0
# Sihlfeld                           1334        1530            1        5271
# Kreis 4                            4276        8691            1        7325
# Werd                               3087        2536            1         610
# Langstrasse                         555        3574            1        5553
# Hard                                634        2581            4        1162
# Kreis 5                            4817        3591            0       44909
# Gewerbeschule                         0         379            0        2344
# Escher Wyss                        4817        3212            0       42565
# Kreis 6                            2635        3961            1        5322
# Unterstrass                        2384        2860            1        5322
# Oberstrass                          251        1101            1           0
# Kreis 7                            2302        3875            0        3886
# Fluntern                              0         557            0          66
# Hottingen                           990        2159            1        3030
# Hirslanden                         1112        1159            1         674
# Witikon                             200           0            0         116
# Kreis 8                            5995       11065            2       15127
# Seefeld                            2353        5585            2        9473
# Mühlebach                          3352        4914            2        4740
# Weinegg                             290         566            0         914
# Kreis 9                           29739       29526            2       42610
# Albisrieden                        5383        6127            3        3382
# Altstetten                        24356       23399            2       39228
# Kreis 10                            159         285            0         220
# Höngg                                 0           0            0         220
# Wipkingen                           159         285            0           0
# Kreis 11                          33757       50811            4       25972
# Affoltern                            98         546            0         200
# Oerlikon                          13603        5104            1        3101
# Seebach                           20056       45161            7       22671
# Kreis 12                            836        1184            1        1059
# Saatlen                             758        1018            3         514
# Schwamendingen-Mitte                 78         166            0         545
# Hirzenbach                            0           0            0           0
#
#                       Unnamed: 4
# NaN                         2014
# Ganze Stadt               264548
# Kreis 1                    53774
# Rathaus                     2284
# Hochschulen                 2218
# Lindenhof                   7381
# City                       41891
# Kreis 2                    34236
# Wollishofen                 9101
# Leimbach                     401
# Enge                       24734
# Kreis 3                    34681
# Alt-Wiedikon               26935
# Friesenberg                    0
# Sihlfeld                    7746
# Kreis 4                     7046
# Werd                        3026
# Langstrasse                 3769
# Hard                         251
# Kreis 5                    33643
# Gewerbeschule               4311
# Escher Wyss                29332
# Kreis 6                     2095
# Unterstrass                 1795
# Oberstrass                   300
# Kreis 7                     3577
# Fluntern                      66
# Hottingen                   1208
# Hirslanden                  2187
# Witikon                      116
# Kreis 8                    13214
# Seefeld                     8101
# Mühlebach                   4779
# Weinegg                      334
# Kreis 9                    41216
# Albisrieden                 4823
# Altstetten                 36393
# Kreis 10                    1240
# Höngg                          0
# Wipkingen                   1240
# Kreis 11                   38549
# Affoltern                   1095
# Oerlikon                    3299
# Seebach                    34155
# Kreis 12                    1277
# Saatlen                      408
# Schwamendingen-Mitte         709
# Hirzenbach                   160

# %%
df = pd.read_excel('Daten/Gewerbe/Leerflaechen-Gewerbe_alle.xlsx', header=9).fillna(0).astype(int)

#df = pd.read_excel('Leerflaechen einzeln.xlsx', index_col=0, header=0)

# %%
df.fillna(0).head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN                     2018        2017        2016        2015        2014
# Ganze Stadt           187714      243660      237054      256450      264548
# Kreis 1                30550       34710       32201       40945       53774
# Rathaus                 3504        1940        2261        2261        2284
# Hochschulen              670        1187         340         126        2218
#
#              Leerfläche (m²).1  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# NaN                       2018        2017        2016        2015
# Ganze Stadt             139664      174381      193027      207901
# Kreis 1                  23805       29535       29807       36180
# Rathaus                   1399        1940        1315        2113
# Hochschulen                670         797         340         126
#
#              Unnamed: 9  Leerflächenziffer  Unnamed: 11  Unnamed: 12  \
# NaN                2014               2018         2017         2016
# Ganze Stadt      214900                  1            2            2
# Kreis 1           49692                  3            3            3
# Rathaus            1856                  1            1            1
# Hochschulen        2218                  0            1            0
#
#              Unnamed: 13  Unnamed: 14  Leerfläche (m²).2  Unnamed: 16  \
# NaN                 2015         2014               2018         2018
# Ganze Stadt            2            2              31663         5381
# Kreis 1                4            6               2436         1889
# Rathaus                2            1                128          383
# Hochschulen            0            2                  0            0
#
#              Unnamed: 17  Unnamed: 18
# NaN                 2018         2018
# Ganze Stadt         5122         5884
# Kreis 1              214         2206
# Rathaus               64         1530
# Hochschulen            0            0

# %%
list2 = list(df)

# %%
list2
# Out:
# ['Leerfläche (m²)',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Leerfläche (m²).1',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Leerflächenziffer',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Leerfläche (m²).2',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18']

# %%
df_leerflaeche = df[['Leerfläche (m²)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']]

# %%
df_leerflaeche.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# NaN                     2018        2017        2016        2015        2014
# Ganze Stadt           187714      243660      237054      256450      264548
# Kreis 1                30550       34710       32201       40945       53774
# Rathaus                 3504        1940        2261        2261        2284
# Hochschulen              670        1187         340         126        2218

# %%
df.rename(columns=df.iloc[0]).drop(df.index[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/base.py in __repr__(self)
#      80         Yields Bytestring in Py2, Unicode String in py3.
#      81         """
# ---> 82         return str(self)
#      83
#      84
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/base.py in __str__(self)
#      59
#      60         if compat.PY3:
# ---> 61             return self.__unicode__()
#      62         return self.__bytes__()
#      63
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __unicode__(self)
#     661             width = None
#     662         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 663                        line_width=width, show_dimensions=show_dimensions)
#     664
#     665         return buf.getvalue()
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1969                                            max_cols=max_cols,
#    1970                                            show_dimensions=show_dimensions)
# -> 1971         formatter.to_string()
#    1972
#    1973         if buf is None:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     609         else:
#     610
# --> 611             strcols = self._to_str_columns()
#     612             if self.line_width is None:  # no need to wrap around just print
#     613                 # the whole frame
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     537                 str_columns = [[label] for label in self.header]
#     538             else:
# --> 539                 str_columns = self._get_formatted_column_labels(frame)
#     540
#     541             stringified = []
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatted_column_labels(self, frame)
#     794                             need_leadsp[x] else x]
#     795                            for i, (col, x) in enumerate(zip(columns,
# --> 796                                                             fmt_columns))]
#     797
#     798         if self.show_index_names and self.has_index_names:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#     793             str_columns = [[' ' + x if not self._get_formatter(i) and
#     794                             need_leadsp[x] else x]
# --> 795                            for i, (col, x) in enumerate(zip(columns,
#     796                                                             fmt_columns))]
#     797
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     368             if is_integer(i) and i not in self.columns:
#     369                 i = self.columns[i]
# --> 370             return self.formatters.get(i, None)
#     371
#     372
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     694
#     695             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 696                                 show_dimensions=show_dimensions, notebook=True)
#     697         else:
#     698             return None
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2035                                            decimal=decimal, table_id=table_id)
#    2036         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2037         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2038
#    2039         if buf is None:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     753                                       table_id=self.table_id)
#     754         if hasattr(self.buf, 'write'):
# --> 755             html_renderer.write_result(self.buf)
#     756         elif isinstance(self.buf, compat.string_types):
#     757             with open(self.buf, 'w') as f:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     178         indent += self.indent_delta
#     179         indent = self._write_header(indent)
# --> 180         indent = self._write_body(indent)
#     181
#     182         self.write('</table>', indent)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     334         fmt_values = {}
#     335         for i in range(min(len(self.columns), self.max_cols)):
# --> 336             fmt_values[i] = self.fmt._format_col(i)
#     337
#     338         # write values
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     722     def _format_col(self, i):
#     723         frame = self.tr_frame
# --> 724         formatter = self._get_formatter(i)
#     725         values_to_format = frame.iloc[:, i]._formatting_values()
#     726         return format_array(values_to_format, formatter,
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatter(self, i)
#     368             if is_integer(i) and i not in self.columns:
#     369                 i = self.columns[i]
# --> 370             return self.formatters.get(i, None)
#     371
#     372
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
df_leerflaeche[:4]
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# NaN                     2018        2017        2016        2015        2014
# Ganze Stadt           187714      243660      237054      256450      264548
# Kreis 1                30550       34710       32201       40945       53774
# Rathaus                 3504        1940        2261        2261        2284

# %%
#df_leerflaeche.rename(columns = header)

# %%
df_leerflaeche.head()
# Out:
#              Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# NaN                     2018        2017        2016        2015        2014
# Ganze Stadt           187714      243660      237054      256450      264548
# Kreis 1                30550       34710       32201       40945       53774
# Rathaus                 3504        1940        2261        2261        2284
# Hochschulen              670        1187         340         126        2218

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

# %%
df_auswahl = df[['2018', '2017']]


#df_auswahl = df[['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1']]



# df_ohnere_total = df[['Industrie - Total', 'Dienste - Total', 'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        #'Pro memoria: Grundstücks- und Wohnungswesen',
#        #'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen'
#         ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-2e842b86821e> in <module>
# ----> 1 df_auswahl = df[['2018', '2017']]
#       2
#       3
#       4 #df_auswahl = df[['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1']]
#       5
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['2018' '2017'] not in index"

# %%
df.columns
# Out:
# Int64Index([187714, 243660, 237054, 256450, 264548, 139664, 174381, 193027,
#             207901, 214900,      1,      2,      2,      2,      2,  31663,
#               5381,   5122,   5884],
#            dtype='int64', name='Ganze Stadt')

# %%
df_auswahl[0:].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dc5c028e240e> in <module>
# ----> 1 df_auswahl[0:].reset_index()
#
# NameError: name 'df_auswahl' is not defined

# %%
df[0:]

# %%
df.transpose()

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import numpy as np

pyo.init_notebook_mode(connected=True)

np.random.seed(42)
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
)]
fig = go.Figure(data=data)
pyo.iplot(fig, filename='hover-chart-basic')

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import numpy as np

pyo.init_notebook_mode(connected=True)

trace1 = go.Bar(
    x=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
    y=['2014', '2015', '2016', '2017', '2018'],
    name='BE Zoo'
)

trace2 = go.Bar(
    x=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
    y=['2014', '2015', '2016', '2017', '2018'],
    name='ZH Zoo'
)

# trace1 = go.Bar(
#     x=['2014', '2015', '2016', '2017', '2018'],
#     y=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
#     name='SF Zoo'
# )
# trace2 = go.Bar(
#     x=['2014', '2015', '2016', '2017', '2018'],
#     y=['Rathaus', 'Hochschulen', 'Lindenhof', 'City'],
#     name='LA Zoo'
# )

data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data)
pyo.iplot(fig, filename='hover-chart-basic')


# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='grouped-bar')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="a4b0fa35-d72b-4bab-b9d0-b9358623824a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a4b0fa35-d72b-4bab-b9d0-b9358623824a", [{"name": "BE Zoo", "x": ["Rathaus", "Hochschulen", "Lindenhof", "City"], "y": ["2014", "2015", "2016", "2017", "2018"], "type": "bar", "uid": "7efc52fa-ff1c-491b-9cc0-5179d4612f7e"}, {"name": "ZH Zoo", "x": ["Rathaus", "Hochschulen", "Lindenhof", "City"], "y": ["2014", "2015", "2016", "2017", "2018"], "type": "bar", "uid": "bcd79ab6-c64d-417e-b516-87c794ee9637"}], {}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("a4b0fa35-d72b-4bab-b9d0-b9358623824a"));});</script>
